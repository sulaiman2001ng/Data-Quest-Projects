# %% [markdown]
# # Profitable App Profiles for the Apple Store and Google Play Markets

# %% [markdown]
# This project will be analyzes data related apps (Mobile App Data) in google and apple store so as to be able to understand user preferences when downloading apps.
#
# The goal of this project is to be able to help companies generate more revenue through a data-driven decision by understanding what type of apps are likely to attarct more users on Google Play and Apple store

# %% [markdown]
# ## Project Work Flow
#
#
# - Definition of project goal
# - Collection of relevant data
# - Data preprocessing and cleaning
# - Data analysis

# %% [markdown]
# <img src="Work_flow_diag.jpg" width="150" height="200">

# %% [markdown]
# ## Opening and Exploring Data

# %% [markdown]
# Collecting data for over 5 million apps (see Figure below) requires a significant amount of time and money, so we'll try to analyze a sample of the data instead. To avoid spending resources on collecting new data ourselves, we have been able to find two data sets from Kaggle, that seem suitable for our goals:
#
# **[Google Play store](https://www.kaggle.com/lava18/google-play-store-apps)**
#
#    - [Direct Link](https://dq-content.s3.amazonaws.com/350/googleplaystore.csv)
#
#
# **[Apple Store store](https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps)**
#
#    - [Direct Link](https://dq-content.s3.amazonaws.com/350/AppleStore.csv)

# %% [markdown]
# ![Figure1](Number_of_Apps_on_Leading_App_stores.jpg)

# %%
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
google = pd.read_csv("googleplaystore.csv")
apple = pd.read_csv("AppleStore.csv")

# %%
google.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
apple.head()
# Out:
#           id               track_name  size_bytes currency  price  \
# 0  284882215                 Facebook   389879808      USD    0.0
# 1  389801252                Instagram   113954816      USD    0.0
# 2  529479190           Clash of Clans   116476928      USD    0.0
# 3  420009108               Temple Run    65921024      USD    0.0
# 4  284035177  Pandora - Music & Radio   130242560      USD    0.0
#
#    rating_count_tot  rating_count_ver  user_rating  user_rating_ver      ver  \
# 0           2974676               212          3.5              3.5     95.0
# 1           2161558              1289          4.5              4.0    10.23
# 2           2130805               579          4.5              4.5  9.24.12
# 3           1724546              3842          4.5              4.0    1.6.2
# 4           1126879              3594          4.0              4.5    8.4.1
#
#   cont_rating        prime_genre  sup_devices.num  ipadSc_urls.num  lang.num  \
# 0          4+  Social Networking               37                1        29
# 1         12+      Photo & Video               37                0        29
# 2          9+              Games               38                5        18
# 3          9+              Games               40                5         1
# 4         12+              Music               37                4         1
#
#    vpp_lic
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %%
google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
google.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7197 entries, 0 to 7196
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                7197 non-null   int64
#  1   track_name        7197 non-null   object
#  2   size_bytes        7197 non-null   int64
#  3   currency          7197 non-null   object
#  4   price             7197 non-null   float64
#  5   rating_count_tot  7197 non-null   int64
#  6   rating_count_ver  7197 non-null   int64
#  7   user_rating       7197 non-null   float64
#  8   user_rating_ver   7197 non-null   float64
#  9   ver               7197 non-null   object
#  10  cont_rating       7197 non-null   object
#  11  prime_genre       7197 non-null   object
#  12  sup_devices.num   7197 non-null   int64
#  13  ipadSc_urls.num   7197 non-null   int64
#  14  lang.num          7197 non-null   int64
#  15  vpp_lic           7197 non-null   int64
# dtypes: float64(3), int64(8), object(5)
# memory usage: 899.8+ KB

# %%
apple.describe()
# Out:
#                  id    size_bytes        price  rating_count_tot  \
# count  7.197000e+03  7.197000e+03  7197.000000      7.197000e+03
# mean   8.631310e+08  1.991345e+08     1.726218      1.289291e+04
# std    2.712368e+08  3.592069e+08     5.833006      7.573941e+04
# min    2.816565e+08  5.898240e+05     0.000000      0.000000e+00
# 25%    6.000937e+08  4.692275e+07     0.000000      2.800000e+01
# 50%    9.781482e+08  9.715302e+07     0.000000      3.000000e+02
# 75%    1.082310e+09  1.819249e+08     1.990000      2.793000e+03
# max    1.188376e+09  4.025970e+09   299.990000      2.974676e+06
#
#        rating_count_ver  user_rating  user_rating_ver  sup_devices.num  \
# count       7197.000000  7197.000000      7197.000000      7197.000000
# mean         460.373906     3.526956         3.253578        37.361817
# std         3920.455183     1.517948         1.809363         3.737715
# min            0.000000     0.000000         0.000000         9.000000
# 25%            1.000000     3.500000         2.500000        37.000000
# 50%           23.000000     4.000000         4.000000        37.000000
# 75%          140.000000     4.500000         4.500000        38.000000
# max       177050.000000     5.000000         5.000000        47.000000
#
#        ipadSc_urls.num     lang.num      vpp_lic
# count      7197.000000  7197.000000  7197.000000
# mean          3.707100     5.434903     0.993053
# std           1.986005     7.919593     0.083066
# min           0.000000     0.000000     0.000000
# 25%           3.000000     1.000000     1.000000
# 50%           5.000000     1.000000     1.000000
# 75%           5.000000     8.000000     1.000000
# max           5.000000    75.000000     1.000000

# %% [markdown]
# ### Exploring Specific rows of the Dataset

# %%
def explore_data(dataset, start, end, rows_columns = False):
    display(dataset.iloc[start:end])
    if rows_columns:
        print("Number of rows: ", dataset.shape[0])
        print("Number of columns: ", dataset.shape[1])

# %%
explore_data(apple, 5, 10, rows_columns=True)
# Out:
#           id        track_name  size_bytes currency  price  rating_count_tot  \
# 5  429047995         Pinterest    74778624      USD    0.0           1061624
# 6  282935706             Bible    92774400      USD    0.0            985920
# 7  553834731  Candy Crush Saga   222846976      USD    0.0            961794
# 8  324684580     Spotify Music   132510720      USD    0.0            878563
# 9  343200656       Angry Birds   175966208      USD    0.0            824451
#
#    rating_count_ver  user_rating  user_rating_ver      ver cont_rating  \
# 5              1814          4.5              4.0     6.26         12+
# 6              5320          4.5              5.0    7.5.1          4+
# 7              2453          4.5              4.5  1.101.0          4+
# 8              8253          4.5              4.5    8.4.3         12+
# 9               107          4.5              3.0    7.4.0          4+
#
#          prime_genre  sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic
# 5  Social Networking               37                5        27        1
# 6          Reference               37                5        45        1
# 7              Games               43                5        24        1
# 8              Music               37                5        18        1
# 9              Games               38                0        10        1
# Number of rows:  7197
# Number of columns:  16

# %%
explore_data(google, 20, 30, rows_columns=True)
# Out:
#                                           App        Category  Rating Reviews  \
# 20                Logo Maker - Small Business  ART_AND_DESIGN     4.0     450
# 21  Boys Photo Editor - Six Pack & Men's Suit  ART_AND_DESIGN     4.1     654
# 22    Superheroes Wallpapers | 4K Backgrounds  ART_AND_DESIGN     4.7    7699
# 23                     Mcqueen Coloring pages  ART_AND_DESIGN     NaN      61
# 24                HD Mickey Minnie Wallpapers  ART_AND_DESIGN     4.7     118
# 25                 Harley Quinn wallpapers HD  ART_AND_DESIGN     4.8     192
# 26              Colorfit - Drawing & Coloring  ART_AND_DESIGN     4.7   20260
# 27                      Animated Photo Editor  ART_AND_DESIGN     4.1     203
# 28                      Pencil Sketch Drawing  ART_AND_DESIGN     3.9     136
# 29            Easy Realistic Drawing Tutorial  ART_AND_DESIGN     4.1     223
#
#     Size  Installs  Type Price Content Rating  \
# 20   14M  100,000+  Free     0       Everyone
# 21   12M  100,000+  Free     0       Everyone
# 22  4.2M  500,000+  Free     0   Everyone 10+
# 23  7.0M  100,000+  Free     0       Everyone
# 24   23M   50,000+  Free     0       Everyone
# 25  6.0M   10,000+  Free     0       Everyone
# 26   25M  500,000+  Free     0       Everyone
# 27  6.1M  100,000+  Free     0       Everyone
# 28  4.6M   10,000+  Free     0       Everyone
# 29  4.2M  100,000+  Free     0       Everyone
#
#                              Genres      Last Updated Current Ver  \
# 20                     Art & Design    April 20, 2018         4.0
# 21                     Art & Design    March 20, 2018         1.1
# 22                     Art & Design     July 12, 2018     2.2.6.2
# 23  Art & Design;Action & Adventure     March 7, 2018       1.0.0
# 24                     Art & Design      July 7, 2018       1.1.3
# 25                     Art & Design    April 25, 2018         1.5
# 26          Art & Design;Creativity  October 11, 2017       1.0.8
# 27                     Art & Design    March 21, 2018        1.03
# 28                     Art & Design     July 12, 2018         6.0
# 29                     Art & Design   August 22, 2017         1.0
#
#      Android Ver
# 20    4.1 and up
# 21  4.0.3 and up
# 22  4.0.3 and up
# 23    4.1 and up
# 24    4.1 and up
# 25    3.0 and up
# 26  4.0.3 and up
# 27  4.0.3 and up
# 28    2.3 and up
# 29    2.3 and up
# Number of rows:  10841
# Number of columns:  13

# %% [markdown]
# **Google app store dataset**
#  - Number of rows: 10,841
#  - Number of columns: 13
#
#
#  **Apple play store dataset**
#   - Number of rows: 7,197
#   - Number of columns: 16

# %%
google.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
apple.columns
# Out:
# Index(['id', 'track_name', 'size_bytes', 'currency', 'price',
#        'rating_count_tot', 'rating_count_ver', 'user_rating',
#        'user_rating_ver', 'ver', 'cont_rating', 'prime_genre',
#        'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic'],
#       dtype='object')

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Deleting Wrong Data
#
# Recall that at our company, we only build apps that are free to download and install, and we design them for an English-speaking audience. This means that we'll need to do the following:
#  - Remove non-English apps like 爱奇艺PPS -《欢乐颂2》电视剧热播.
#  - Remove apps that aren't free.
#
#
# In other to do the data cleaning effectively, going through the discussion sections will be a good start, so as to find out erros in the datasets that might have been discussed.
#
# The Google Play dataset has a [dedicated discussion section](https://www.kaggle.com/lava18/google-play-store-apps/discussion), and we can see that
#  - [one of the discussions](https://www.kaggle.com/lava18/google-play-store-apps/discussion/66015) describes "Wrong Entry for 10472 row".
#  -
#
# Also for the apple store the [dedicated section](https://www.kaggle.com/datasets/ramamet4/app-store-apple-data-set-10k-apps/discussion?select=appleStore_description.csv)

# %%
google.iloc[10472]
# Out:
# App               Life Made WI-Fi Touchscreen Photo Frame
# Category                                              1.9
# Rating                                                 19
# Reviews                                              3.0M
# Size                                               1,000+
# Installs                                             Free
# Type                                                    0
# Price                                            Everyone
# Content Rating                                        NaN
# Genres                                  February 11, 2018
# Last Updated                                       1.0.19
# Current Ver                                    4.0 and up
# Android Ver                                           NaN
# Name: 10472, dtype: object

# %% [markdown]
# It can be obsrved that the category section is missing and the records shifted left creating no record for *Android ver* column.
#
# Thus this row will be deleted

# %%
google.iloc[10471:10474]
# Out:
#                                            App         Category  Rating  \
# 10471                         Xposed Wi-Fi-Pwd  PERSONALIZATION     3.5
# 10472  Life Made WI-Fi Touchscreen Photo Frame              1.9    19.0
# 10473                  osmino Wi-Fi: free WiFi            TOOLS     4.2
#
#       Reviews    Size     Installs  Type     Price Content Rating  \
# 10471    1042    404k     100,000+  Free         0       Everyone
# 10472    3.0M  1,000+         Free     0  Everyone            NaN
# 10473  134203    4.1M  10,000,000+  Free         0       Everyone
#
#                   Genres    Last Updated Current Ver   Android Ver
# 10471    Personalization  August 5, 2014       3.0.0  4.0.3 and up
# 10472  February 11, 2018          1.0.19  4.0 and up           NaN
# 10473              Tools  August 7, 2018     6.06.14    4.4 and up

# %% [markdown]
# ### Removing Duplicate Enteries
#
# From [a specific discussion forum](https://www.kaggle.com/datasets/lava18/google-play-store-apps/discussion/67894?search=duplicate) thread, notice of duplicate entries for several apps was observed - where many of the duplicate entries differ only by review count.

# %%
print("Google App Duplicates: ", google.duplicated(subset='App').sum())
print("Apple App Duplicates: ", apple.duplicated(subset='track_name').sum())
# Out:
# Google App Duplicates:  1181
# Apple App Duplicates:  2

# %% [markdown]
# There are are 1,181 duplicate apps in google app store in this dataset
#
# While 2 are in apple dataset

# %%
google[google.duplicated(subset='App')].head(10)
# Out:
#                               App  Category  Rating Reviews  \
# 229  Quick PDF Scanner + OCR FREE  BUSINESS     4.2   80805
# 236                           Box  BUSINESS     4.2  159872
# 239            Google My Business  BUSINESS     4.4   70991
# 256           ZOOM Cloud Meetings  BUSINESS     4.4   31614
# 261     join.me - Simple Meetings  BUSINESS     4.0    6989
# 265                           Box  BUSINESS     4.2  159872
# 266                      Zenefits  BUSINESS     4.2     296
# 267                    Google Ads  BUSINESS     4.3   29313
# 268            Google My Business  BUSINESS     4.4   70991
# 269                         Slack  BUSINESS     4.4   51507
#
#                    Size     Installs  Type Price Content Rating    Genres  \
# 229  Varies with device   5,000,000+  Free     0       Everyone  Business
# 236  Varies with device  10,000,000+  Free     0       Everyone  Business
# 239  Varies with device   5,000,000+  Free     0       Everyone  Business
# 256                 37M  10,000,000+  Free     0       Everyone  Business
# 261  Varies with device   1,000,000+  Free     0       Everyone  Business
# 265  Varies with device  10,000,000+  Free     0       Everyone  Business
# 266                 14M      50,000+  Free     0       Everyone  Business
# 267                 20M   5,000,000+  Free     0       Everyone  Business
# 268  Varies with device   5,000,000+  Free     0       Everyone  Business
# 269  Varies with device   5,000,000+  Free     0       Everyone  Business
#
#           Last Updated         Current Ver         Android Ver
# 229  February 26, 2018  Varies with device        4.0.3 and up
# 236      July 31, 2018  Varies with device  Varies with device
# 239      July 24, 2018    2.19.0.204537701          4.4 and up
# 256      July 20, 2018      4.1.28165.0716          4.0 and up
# 261      July 16, 2018           4.3.0.508          4.4 and up
# 265      July 31, 2018  Varies with device  Varies with device
# 266      June 15, 2018               3.2.1          4.1 and up
# 267      July 30, 2018              1.12.0        4.0.3 and up
# 268      July 24, 2018    2.19.0.204537701          4.4 and up
# 269     August 2, 2018  Varies with device  Varies with device

# %%
apple[apple.duplicated(subset='track_name')]
# Out:
#               id           track_name  size_bytes currency  price  \
# 4463  1178454060  Mannequin Challenge    59572224      USD    0.0
# 4831  1089824278    VR Roller Coaster   240964608      USD    0.0
#
#       rating_count_tot  rating_count_ver  user_rating  user_rating_ver    ver  \
# 4463               105                58          4.0              4.5  1.0.1
# 4831                67                44          3.5              4.0   0.81
#
#      cont_rating prime_genre  sup_devices.num  ipadSc_urls.num  lang.num  \
# 4463          4+       Games               38                5         1
# 4831          4+       Games               38                0         1
#
#       vpp_lic
# 4463        1
# 4831        1

# %% [markdown]
# Let's see some example of duplicate apps

# %%
google[google['App'] == "Google My Business"]
# Out:
#                     App  Category  Rating Reviews                Size  \
# 193  Google My Business  BUSINESS     4.4   70991  Varies with device
# 239  Google My Business  BUSINESS     4.4   70991  Varies with device
# 268  Google My Business  BUSINESS     4.4   70991  Varies with device
#
#        Installs  Type Price Content Rating    Genres   Last Updated  \
# 193  5,000,000+  Free     0       Everyone  Business  July 24, 2018
# 239  5,000,000+  Free     0       Everyone  Business  July 24, 2018
# 268  5,000,000+  Free     0       Everyone  Business  July 24, 2018
#
#           Current Ver Android Ver
# 193  2.19.0.204537701  4.4 and up
# 239  2.19.0.204537701  4.4 and up
# 268  2.19.0.204537701  4.4 and up

# %%
google[google['App'] == "Quick PDF Scanner + OCR FREE"]
# Out:
#                               App  Category  Rating Reviews  \
# 222  Quick PDF Scanner + OCR FREE  BUSINESS     4.2   80805
# 229  Quick PDF Scanner + OCR FREE  BUSINESS     4.2   80805
# 285  Quick PDF Scanner + OCR FREE  BUSINESS     4.2   80804
#
#                    Size    Installs  Type Price Content Rating    Genres  \
# 222  Varies with device  5,000,000+  Free     0       Everyone  Business
# 229  Varies with device  5,000,000+  Free     0       Everyone  Business
# 285  Varies with device  5,000,000+  Free     0       Everyone  Business
#
#           Last Updated         Current Ver   Android Ver
# 222  February 26, 2018  Varies with device  4.0.3 and up
# 229  February 26, 2018  Varies with device  4.0.3 and up
# 285  February 26, 2018  Varies with device  4.0.3 and up

# %%
google[google['App'] == "Instagram"]
# Out:
#             App Category  Rating   Reviews                Size  \
# 2545  Instagram   SOCIAL     4.5  66577313  Varies with device
# 2604  Instagram   SOCIAL     4.5  66577446  Varies with device
# 2611  Instagram   SOCIAL     4.5  66577313  Varies with device
# 3909  Instagram   SOCIAL     4.5  66509917  Varies with device
#
#             Installs  Type Price Content Rating  Genres   Last Updated  \
# 2545  1,000,000,000+  Free     0           Teen  Social  July 31, 2018
# 2604  1,000,000,000+  Free     0           Teen  Social  July 31, 2018
# 2611  1,000,000,000+  Free     0           Teen  Social  July 31, 2018
# 3909  1,000,000,000+  Free     0           Teen  Social  July 31, 2018
#
#              Current Ver         Android Ver
# 2545  Varies with device  Varies with device
# 2604  Varies with device  Varies with device
# 2611  Varies with device  Varies with device
# 3909  Varies with device  Varies with device

# %%
apple[apple["track_name"] == "VR Roller Coaster"]
# Out:
#               id         track_name  size_bytes currency  price  \
# 4442   952877179  VR Roller Coaster   169523200      USD    0.0
# 4831  1089824278  VR Roller Coaster   240964608      USD    0.0
#
#       rating_count_tot  rating_count_ver  user_rating  user_rating_ver    ver  \
# 4442               107               102          3.5              3.5  2.0.0
# 4831                67                44          3.5              4.0   0.81
#
#      cont_rating prime_genre  sup_devices.num  ipadSc_urls.num  lang.num  \
# 4442          4+       Games               37                5         1
# 4831          4+       Games               38                0         1
#
#       vpp_lic
# 4442        1
# 4831        1

# %%
apple[apple["track_name"] == "Mannequin Challenge"]
# Out:
#               id           track_name  size_bytes currency  price  \
# 2948  1173990889  Mannequin Challenge   109705216      USD    0.0
# 4463  1178454060  Mannequin Challenge    59572224      USD    0.0
#
#       rating_count_tot  rating_count_ver  user_rating  user_rating_ver    ver  \
# 2948               668                87          3.0              3.0    1.4
# 4463               105                58          4.0              4.5  1.0.1
#
#      cont_rating prime_genre  sup_devices.num  ipadSc_urls.num  lang.num  \
# 2948          9+       Games               37                4         1
# 4463          4+       Games               38                5         1
#
#       vpp_lic
# 2948        1
# 4463        1

# %% [markdown]
# #### For Google
# Examining the rows we printed for the 3 apps shown above, where differences are observed in each record, the main difference happens on the *Reviews* column. The difference in the number of reviews show the data was collected at different times.
#
# We can use this information to build a criterion for removing the duplicates. The higher the number of reviews, the more recent the data should be. Rather than removing duplicates randomly, we'll only keep the row with the highest number of reviews and remove the other entries for any given app.
#
# #### For Apple
# While for apple, the differences are in app version. Thus, we will only keep the latest version of the app

# %%
# Firstly, we sort by Reviews with the largest reviews at the top (Descendig order)
# Drop duplicates keeping the largest values, which will be he first
google =  google.sort_values('Reviews', ascending=False)
google_clean = google.drop_duplicates(subset='App', keep='first')

# %%
google_clean[google_clean['App'] == 'Quick PDF Scanner + OCR FREE']
# Out:
#                               App  Category  Rating Reviews  \
# 229  Quick PDF Scanner + OCR FREE  BUSINESS     4.2   80805
#
#                    Size    Installs  Type Price Content Rating    Genres  \
# 229  Varies with device  5,000,000+  Free     0       Everyone  Business
#
#           Last Updated         Current Ver   Android Ver
# 229  February 26, 2018  Varies with device  4.0.3 and up

# %%
google_clean[google_clean['App'] == "Instagram"]
# Out:
#             App Category  Rating   Reviews                Size  \
# 2604  Instagram   SOCIAL     4.5  66577446  Varies with device
#
#             Installs  Type Price Content Rating  Genres   Last Updated  \
# 2604  1,000,000,000+  Free     0           Teen  Social  July 31, 2018
#
#              Current Ver         Android Ver
# 2604  Varies with device  Varies with device

# %%
google_clean.shape
# Out:
# (9660, 13)

# %%
apple = apple.sort_values('ver', ascending=False)
apple_clean = apple.drop_duplicates(subset="track_name", keep="first")

# %%
apple_clean[apple_clean["track_name"] == "VR Roller Coaster"]
# Out:
#              id         track_name  size_bytes currency  price  \
# 4442  952877179  VR Roller Coaster   169523200      USD    0.0
#
#       rating_count_tot  rating_count_ver  user_rating  user_rating_ver    ver  \
# 4442               107               102          3.5              3.5  2.0.0
#
#      cont_rating prime_genre  sup_devices.num  ipadSc_urls.num  lang.num  \
# 4442          4+       Games               37                5         1
#
#       vpp_lic
# 4442        1

# %% [markdown]
# ### Removing Non-English Apps

# %%
# pd.set_option("display.max_rows", None)

# %%
"""
This fucntions is used to separate english and non-english app from the dataset.
Any word which ASCII value is more than 127 and contain more than 3 emoticons 
are referred to as non-english app here
"""
def check_English(word):
    count = 0
    for letter in word:
        if ord(letter) > 127:
            count += 1
    if count >= 3:
        return "non-english"
    else:
        return "english"

# %%
check_English("Instachat 😜")
# Out:
# 'english'

# %%
ord("😜")
# Out:
# 128540

# %%
check_English("教えて!goo")
# Out:
# 'non-english'

# %%
count = 0
for letter in "教えて!goo":
    if ord(letter) > 127:
        count += 1
count
# Out:
# 3

# %%
for letter in "教えて!goo":
    print(letter, ord(letter))
# Out:
# 教 25945
# え 12360
# て 12390
# ! 33
# g 103
# o 111
# o 111

# %%
for letter in "Instachat 😜":
    print(letter, ord(letter))
# Out:
# I 73
# n 110
# s 115
# t 116
# a 97
# c 99
# h 104
# a 97
# t 116
#   32
# 😜 128540

# %%
count = 0
for letter in "教えて!goo":
    if ord(letter) > 127:
        print(ord(letter))
# Out:
# 25945
# 12360
# 12390

# %%
for letter in "Lep's World 3 🍀🍀🍀":
    print(letter, ord(letter))
# Out:
# L 76
# e 101
# p 112
# ' 39
# s 115
#   32
# W 87
# o 111
# r 114
# l 108
# d 100
#   32
# 3 51
#   32
# 🍀 127808
# 🍀 127808
# 🍀 127808

# %%
pd.options.mode.chained_assignment = None  # default='warn'
google_clean["app_language"] = google_clean["App"].map(check_English)

# %%
google_clean[google_clean["app_language"] != "english"]
# Out:
#                                      App             Category  Rating Reviews  \
# 10763                FP Разбитый дисплей               FAMILY     4.5     922
# 9777           FAHREDDİN er-RÂZİ TEFSİRİ  BOOKS_AND_REFERENCE     NaN       9
# 8456                   Lep's World 3 🍀🍀🍀                 GAME     4.3  771001
# 7290      Offline Jízdní řády CG Transit  MAPS_AND_NAVIGATION     4.6    7314
# 6201               CSCS BG (в български)               FAMILY     2.4       7
# ...                                  ...                  ...     ...     ...
# 7751                 الفاتحون Conquerors               FAMILY     4.5  108130
# 9466     パーリーゲイツ公式通販｜EJ STYLE（イージェイスタイル）             SHOPPING     NaN       1
# 5266                       AJ렌터카 법인 카셰어링  MAPS_AND_NAVIGATION     NaN       0
# 8147                  Hlášenírozhlasu.cz        COMMUNICATION     NaN       0
# 9934   I'm Rich/Eu sou Rico/أنا غني/我很有錢            LIFESTYLE     NaN       0
#
#        Size     Installs  Type    Price Content Rating             Genres  \
# 10763  552k      50,000+  Free        0       Everyone      Entertainment
# 9777    20M       1,000+  Free        0       Everyone  Books & Reference
# 8456    52M  50,000,000+  Free        0   Everyone 10+             Action
# 7290   7.0M     100,000+  Free        0       Everyone  Maps & Navigation
# 6201   2.1M         100+  Paid    $3.99       Everyone          Education
# ...     ...          ...   ...      ...            ...                ...
# 7751    40M   5,000,000+  Free        0           Teen           Strategy
# 9466   9.3M         100+  Free        0       Everyone           Shopping
# 5266    27M          10+  Free        0       Everyone  Maps & Navigation
# 8147    17M          10+  Free        0       Everyone      Communication
# 9934    40M           0+  Paid  $399.99       Everyone          Lifestyle
#
#              Last Updated Current Ver   Android Ver app_language
# 10763  September 20, 2014         1.1    1.6 and up  non-english
# 9777       March 19, 2018         1.1  4.0.3 and up  non-english
# 8456        June 11, 2018     2.0.1.3    4.1 and up  non-english
# 7290    September 7, 2017       3.1.4    4.0 and up  non-english
# 6201       March 23, 2017         1.0  4.0.3 and up  non-english
# ...                   ...         ...           ...          ...
# 7751       August 3, 2018       1.8.0    4.0 and up  non-english
# 9466    November 16, 2017         3.0  4.0.3 and up  non-english
# 5266        July 30, 2018     1.0.0.0    4.3 and up  non-english
# 8147        July 27, 2018       2.1.3    4.1 and up  non-english
# 9934     December 1, 2017       MONEY    4.1 and up  non-english
#
# [62 rows x 14 columns]

# %%
for app in google_clean[google_clean["app_language"] != "english"]["App"].unique():
    print(app)
# Out:
# FP Разбитый дисплей
# FAHREDDİN er-RÂZİ TEFSİRİ
# Lep's World 3 🍀🍀🍀
# Offline Jízdní řády CG Transit
# CSCS BG (в български)
# あなカレ【BL】無料ゲーム
# M3-X5-X6-M-İ3-İ8 RACİNG 2018
# Égalité et Réconciliation
# ECナビ×シュフー
# Flame - درب عقلك يوميا
# 英漢字典 EC Dictionary
# DG ग्राम / Digital Gram Panchayat
# 乗換NAVITIME　Timetable & Route Search in Japan Tokyo
# L.POINT - 엘포인트 [ 포인트, 멤버십, 적립, 사용, 모바일 카드, 쿠폰, 롯데]
# РИА Новости
# 뽕티비 - 개인방송, 인터넷방송, BJ방송
# RMEduS - 음성인식을 활용한 R 프로그래밍 실습 시스템
# Modlitební knížka CZ
# BL 女性向け恋愛ゲーム◆俺プリクロス
# My AEK - Official ΑΕΚ FC app
# CNY Slots : Gong Xi Fa Cai 发财机
# EG SIM CARD (EGSIMCARD, 이지심카드)
# أحداث وحقائق | خبر عاجل في اخبار العالم
# Sona - Nær við allastaðni
# Ay Yıldız Duvar Kağıtları
# CK 初一 十五
# РееI Smart Remote MP3 CD Player
# At home - rental · real estate · room finding application such as apartment · apartment
# 哈哈姆特不EY
# لعبة تقدر تربح DZ
# Bonjour 2017 Abidjan CI ❤❤❤❤❤
# 乐屋网: Buying a house, selling a house, renting a house
# သိင်္ Astrology - Min Thein Kha BayDin
# BS Calendar / Patro / पात्रो
# 日本AV历史
# Билеты ПДД CD 2019 PRO
# 中国語 AQリスニング
# Vip视频免费看-BT磁力搜索
# DM הפקות
# AÖF Ev İdaresi 1. Sınıf
# বাংলা টিভি প্রো BD Bangla TV
# BQ-መጽሐፍ ቅዱሳዊ ጥያቄዎች
# BL 女性向け恋愛ゲーム◆ごくメン
# 감성학원 BL 첫사랑
# 📏 Smart Ruler ↔️ cm/inch measuring for homework!
# Al Quran Free - القرآن (Islam)
# Neuvaines et prières au Coeur Sacré de Jésus
# RPG ブレイジング ソウルズ アクセレイト
# SecondSecret ‐「恋を読む」BLノベルゲーム‐
# Truyện Vui Tý Quậy
# Ey Sey Storytime រឿងនិទានតាឥសី
# ► MultiCraft ― Free Miner! 👍
# صور حرف H
# Cъновник BG
# Météo Algérie DZ
# বাংলাflix
# DW فارسی By dw-arab.com
# الفاتحون Conquerors
# パーリーゲイツ公式通販｜EJ STYLE（イージェイスタイル）
# AJ렌터카 법인 카셰어링
# Hlášenírozhlasu.cz
# I'm Rich/Eu sou Rico/أنا غني/我很有錢

# %%
# Dropping the apps that are not englsh
google_clean_english = google_clean[google_clean["app_language"] == "english"]

# %%
google_clean_english[google_clean_english["App"] == "教えて!goo"]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver, app_language]
# Index: []

# %%
google_clean_english.shape
# Out:
# (9598, 14)

# %%
google_clean.shape
# Out:
# (9660, 14)

# %%
# Repeating the same thing for apple apps

apple_clean["app_language"] = apple_clean["track_name"].map(check_English)
apple_clean_english = apple_clean[apple_clean["app_language"] == "english"]
print(apple_clean.shape)
print(apple_clean_english.shape)
# Out:
# (7195, 17)
# (6153, 17)

# %%
apple_clean[apple_clean["app_language"] != "english"]
# Out:
#               id                     track_name  size_bytes currency  price  \
# 5306   931337752                    幻獣契約クリプトラクト    97223680      USD    0.0
# 5455   983202217                乐视体育—英超欧冠F1高清直播   121336832      USD    0.0
# 2592   452186370          百度地图-智能的手机导航，公交地铁出行必备   213586944      USD    0.0
# 5083   564713751                        51信用卡管家    68952064      USD    0.0
# 3065   452176796              蘑菇街-网红直播搭配的购物特卖平台   144661504      USD    0.0
# ...          ...                            ...         ...      ...    ...
# 6270   977041956   最長１週間の献立が簡単に作れるme:new（ミーニュー）    39937024      USD    0.0
# 5706   794156760              ゆるドラシル -本格派神話RPG-    91238400      USD    0.0
# 6834  1074321709         バーチャル恵方巻【節分・恵方コンパス・方位】     5177344      USD    0.0
# 5638  1144397186  エレメンタル ファンタジー - 高精細３ＤアクションＲＰＧ   173584384      USD    0.0
# 6030  1170455562            迷你世界-国产精品沙盒联机生存建造游戏   106102784      USD    0.0
#
#       rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 5306                33                 0          4.0              0.0
# 5455                24                 0          3.5              0.0
# 2592              1014                23          4.0              4.5
# 5083                47                 0          4.0              0.0
# 3065               558                 0          5.0              0.0
# ...                ...               ...          ...              ...
# 6270                 0                 0          0.0              0.0
# 5706                14                 0          4.5              0.0
# 6834                 0                 0          0.0              0.0
# 5638                17                 0          5.0              0.0
# 6030                 5                 0          3.5              0.0
#
#            ver cont_rating   prime_genre  sup_devices.num  ipadSc_urls.num  \
# 5306    v3.6.9          9+         Games               40                5
# 5455    V3.7.0         17+        Sports               38                0
# 2592     9.8.2         17+    Navigation               37                0
# 5083     9.4.1          4+       Finance               38                4
# 3065     9.4.1         17+      Shopping               37                0
# ...        ...         ...           ...              ...              ...
# 6270     1,2.4          4+  Food & Drink               38                4
# 5706  01.44.02          4+         Games               37                5
# 6834  00.00.09          4+    Navigation               40                5
# 5638  0.17.518         12+         Games               38                5
# 6030    0.16.3          4+         Games               38                5
#
#       lang.num  vpp_lic app_language
# 5306         1        1  non-english
# 5455         4        1  non-english
# 2592         2        1  non-english
# 5083         2        1  non-english
# 3065         4        1  non-english
# ...        ...      ...          ...
# 6270         2        1  non-english
# 5706         1        1  non-english
# 6834         1        1  non-english
# 5638         1        1  non-english
# 6030         2        1  non-english
#
# [1042 rows x 17 columns]

# %% [markdown]
# ###  Isolating the Free Apps
#
# As we mentioned in the introduction, we only build apps that are free to download and install, and our main source of revenue consists of in-app ads. Our datasets contain both free and non-free apps; we'll need to isolate only the free apps for our analysis.
#
# This will be done by identifying the price column retaining only that have zero as the price

# %%
google_clean_english.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9598 entries, 2989 to 4177
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9598 non-null   object
#  1   Category        9598 non-null   object
#  2   Rating          8153 non-null   float64
#  3   Reviews         9598 non-null   object
#  4   Size            9598 non-null   object
#  5   Installs        9598 non-null   object
#  6   Type            9597 non-null   object
#  7   Price           9598 non-null   object
#  8   Content Rating  9597 non-null   object
#  9   Genres          9598 non-null   object
#  10  Last Updated    9598 non-null   object
#  11  Current Ver     9590 non-null   object
#  12  Android Ver     9595 non-null   object
#  13  app_language    9598 non-null   object
# dtypes: float64(1), object(13)
# memory usage: 1.1+ MB

# %%
google_clean_2 = google_clean_english[google_clean_english["Price"] == "0"]
# google_clean_2 = google_clean_english[google_clean_english["Type"] == "Free"]

# %%
google_clean_2.head()
# Out:
#                                     App          Category  Rating Reviews  \
# 2989             GollerCepte Live Score            SPORTS     4.2    9992
# 4970       Ad Block REMOVER - NEED ROOT             TOOLS     3.3     999
# 2723                SnipSnap Coupon App          SHOPPING     4.2    9975
# 3079  US Open Tennis Championships 2018            SPORTS     4.0    9971
# 3229                         DreamTrips  TRAVEL_AND_LOCAL     4.7    9971
#
#      Size    Installs  Type Price Content Rating          Genres  \
# 2989  31M  1,000,000+  Free     0       Everyone          Sports
# 4970  91k    100,000+  Free     0       Everyone           Tools
# 2723  18M  1,000,000+  Free     0       Everyone        Shopping
# 3079  33M  1,000,000+  Free     0       Everyone          Sports
# 3229  22M    500,000+  Free     0           Teen  Travel & Local
#
#            Last Updated Current Ver Android Ver app_language
# 2989       May 23, 2018         6.5  4.1 and up      english
# 4970  December 17, 2013         3.2  2.2 and up      english
# 2723   January 22, 2018         1.4  4.3 and up      english
# 3079       June 5, 2018         7.1  5.0 and up      english
# 3229     August 6, 2018      1.28.1  5.0 and up      english

# %%
google_clean_2.shape
# Out:
# (8846, 14)

# %%
google_clean[(google_clean['Type'] != "Free") & (google_clean['Price'] == '0')]
# Out:
#                             App Category  Rating Reviews                Size  \
# 9148  Command & Conquer: Rivals   FAMILY     NaN       0  Varies with device
#
#      Installs Type Price Content Rating    Genres   Last Updated  \
# 9148        0  NaN     0   Everyone 10+  Strategy  June 28, 2018
#
#              Current Ver         Android Ver app_language
# 9148  Varies with device  Varies with device      english

# %%
apple_clean_english.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6153 entries, 1169 to 4610
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                6153 non-null   int64
#  1   track_name        6153 non-null   object
#  2   size_bytes        6153 non-null   int64
#  3   currency          6153 non-null   object
#  4   price             6153 non-null   float64
#  5   rating_count_tot  6153 non-null   int64
#  6   rating_count_ver  6153 non-null   int64
#  7   user_rating       6153 non-null   float64
#  8   user_rating_ver   6153 non-null   float64
#  9   ver               6153 non-null   object
#  10  cont_rating       6153 non-null   object
#  11  prime_genre       6153 non-null   object
#  12  sup_devices.num   6153 non-null   int64
#  13  ipadSc_urls.num   6153 non-null   int64
#  14  lang.num          6153 non-null   int64
#  15  vpp_lic           6153 non-null   int64
#  16  app_language      6153 non-null   object
# dtypes: float64(3), int64(8), object(6)
# memory usage: 865.3+ KB

# %%
apple_clean_2 = apple_clean_english[apple_clean_english["price"] == 0]

# %%
apple_clean_2.head()
# Out:
#               id                                    track_name  size_bytes  \
# 1169   945621521  Quick Hit Slots – Casino Slot Machines Games   186679296
# 224    491730359                                        The CW    30552064
# 4031  1023683909               Alliance Wars: World Domination   493512704
# 2984  1028464453             Strawberry Shortcake Candy Garden   232399872
# 0      284882215                                      Facebook   389879808
#
#      currency  price  rating_count_tot  rating_count_ver  user_rating  \
# 1169      USD    0.0              7646                46          4.0
# 224       USD    0.0             97368                 9          4.5
# 4031      USD    0.0               176                 6          5.0
# 2984      USD    0.0               633               633          4.5
# 0         USD    0.0           2974676               212          3.5
#
#       user_rating_ver         ver cont_rating        prime_genre  \
# 1169              4.0     v2.2.21         17+              Games
# 224               3.5     v2.13.9         12+      Entertainment
# 4031              5.0      v1.865         12+              Games
# 2984              4.5  Update 1.1          4+      Entertainment
# 0                 3.5        95.0          4+  Social Networking
#
#       sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic app_language
# 1169               38                5         1        1      english
# 224                37                5         9        1      english
# 4031               38                1         1        1      english
# 2984               39                5        10        1      english
# 0                  37                1        29        1      english

# %%
apple_clean_2.shape
# Out:
# (3201, 17)

# %% [markdown]
# ## Most Common Apps by Genre
#
# If you could recall, our goal is to determine the kinds of apps that are likely to attract more users because the number of people using our apps affect our revenue.
#
# Thus, in other to do this, we identify the most common genres for both google play store and IOS store. For this, we'll need to build frequency tables for a few columns in our datasets.

# %% [markdown]
# ### Google Store

# %%
google_clean_2["Category"].value_counts(normalize=True)*100
# Out:
# FAMILY                 18.991635
# GAME                    9.654081
# TOOLS                   8.444495
# BUSINESS                4.600950
# PRODUCTIVITY            3.900068
# LIFESTYLE               3.888763
# FINANCE                 3.707891
# MEDICAL                 3.527018
# SPORTS                  3.391363
# PERSONALIZATION         3.323536
# COMMUNICATION           3.233100
# HEALTH_AND_FITNESS      3.086141
# PHOTOGRAPHY             2.950486
# NEWS_AND_MAGAZINES      2.803527
# SOCIAL                  2.667872
# TRAVEL_AND_LOCAL        2.340041
# SHOPPING                2.249604
# BOOKS_AND_REFERENCE     2.136559
# DATING                  1.865250
# VIDEO_PLAYERS           1.797423
# MAPS_AND_NAVIGATION     1.390459
# FOOD_AND_DRINK          1.243500
# EDUCATION               1.164368
# ENTERTAINMENT           0.960886
# LIBRARIES_AND_DEMO      0.938277
# AUTO_AND_VEHICLES       0.926973
# HOUSE_AND_HOME          0.802623
# WEATHER                 0.791318
# EVENTS                  0.712186
# PARENTING               0.655664
# ART_AND_DESIGN          0.644359
# COMICS                  0.610445
# BEAUTY                  0.599141
# Name: Category, dtype: float64

# %%
google_clean_2["Genres"].value_counts(normalize=True)*100
# Out:
# Tools                              8.433190
# Entertainment                      6.081845
# Education                          5.358354
# Business                           4.600950
# Productivity                       3.900068
#                                      ...
# Puzzle;Education                   0.011305
# Art & Design;Pretend Play          0.011305
# Strategy;Action & Adventure        0.011305
# Casual;Music & Video               0.011305
# Art & Design;Action & Adventure    0.011305
# Name: Genres, Length: 115, dtype: float64

# %% [markdown]
# ### Apple Store

# %%
apple_clean_2["prime_genre"].value_counts(normalize=True)*100
# Out:
# Games                58.231803
# Entertainment         7.841300
# Photo & Video         4.998438
# Education             3.686348
# Social Networking     3.311465
# Shopping              2.592940
# Utilities             2.467979
# Sports                2.155576
# Music                 2.061856
# Health & Fitness      2.030615
# Productivity          1.749453
# Lifestyle             1.562012
# News                  1.343330
# Travel                1.249609
# Finance               1.093408
# Weather               0.874727
# Food & Drink          0.812246
# Business              0.531084
# Reference             0.531084
# Book                  0.374883
# Navigation            0.187441
# Medical               0.187441
# Catalogs              0.124961
# Name: prime_genre, dtype: float64

# %% [markdown]
# ## Most Popular apps Genre on the App store
#
# Here we want to determine the kind of apps with the most users. One way to find out what genres are the most popular (have the most users) is to calculate the average number of installs for each app genre. As a workaround, we'll take the total number of user ratings as a proxy, which we can find in the rating_count_tot app.

# %%
apple_group = apple_clean_2.groupby("prime_genre")

# %%
apple_group.groups.keys()
# Out:
# dict_keys(['Book', 'Business', 'Catalogs', 'Education', 'Entertainment', 'Finance', 'Food & Drink', 'Games', 'Health & Fitness', 'Lifestyle', 'Medical', 'Music', 'Navigation', 'News', 'Photo & Video', 'Productivity', 'Reference', 'Shopping', 'Social Networking', 'Sports', 'Travel', 'Utilities', 'Weather'])

# %%
apple_group.get_group("Book")
# Out:
#               id                                         track_name  \
# 77     302584613        Kindle – Read eBooks, Magazines & Textbooks
# 5875  1064016503                           MangaZERO - comic reader
# 285    366869252          OverDrive – Library eBooks and Audiobooks
# 6796  1064016216                     MangaTiara - love comic reader
# 6647   855062660                                         ikouhoushi
# 364   1024818709                              HOOKED - Chat Stories
# 208    379693831  Audible – audio books, original series & podcasts
# 244   1031002863       Color Therapy Adult Coloring Book for Adults
# 2704   482728980  BookShout: Read eBooks & Track Your Reading Goals
# 3232   909110675            Dr. Seuss Treasury — 50 best kids books
# 3954   934390663                                    Weirdwood Manor
# 3369   977242839                                  Green Riding Hood
#
#       size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 77     169747456      USD    0.0            252076                80
# 5875    99365888      USD    0.0                 9                 3
# 285     39844864      USD    0.0             65450              2721
# 6796    81198080      USD    0.0                 0                 0
# 6647    58945536      USD    0.0                 0                 0
# 364     94545920      USD    0.0             47829               708
# 208     81558528      USD    0.0            105274              1774
# 244    135236608      USD    0.0             84062              1450
# 2704   106071040      USD    0.0               879                22
# 3232   100943872      USD    0.0               451                31
# 3954   342845440      USD    0.0               197                 5
# 3369   316589056      USD    0.0               392                 2
#
#       user_rating  user_rating_ver     ver cont_rating prime_genre  \
# 77            3.5              4.5    5.11          4+        Book
# 5875          4.5              3.5   4.0.2         17+        Book
# 285           4.0              4.5   3.6.4          4+        Book
# 6796          0.0              0.0   3.4.2         17+        Book
# 6647          0.0              0.0  3.1.83         17+        Book
# 364           4.5              4.5  2.28.0          9+        Book
# 208           4.5              4.5    2.23          4+        Book
# 244           5.0              4.5     2.0          4+        Book
# 2704          4.0              3.5    10.1         12+        Book
# 3232          4.5              4.5   1.8.3          4+        Book
# 3954          4.5              5.0   1.5.1          4+        Book
# 3369          4.0              5.0   1.2.1          4+        Book
#
#       sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic app_language
# 77                 37                5         9        1      english
# 5875               37                4         2        1      english
# 285                37                5        18        1      english
# 6796               37                0         1        1      english
# 6647               37                1         3        1      english
# 364                37                0         8        1      english
# 208                37                5         5        1      english
# 244                37                4         2        1      english
# 2704               37                5         1        1      english
# 3232               37                4         1        1      english
# 3954               37                5         1        1      english
# 3369               37                5        12        1      english

# %%
apple_group.get_group("Book")["rating_count_tot"].sum()
# Out:
# 556619

# %%
apple_group.get_group("Book")["rating_count_tot"].count()
# Out:
# 12

# %%
apple_group.get_group("Book")["rating_count_tot"].shape[0]
# Out:
# 12

# %%
# apple_popular = {genre: apple_group.get_group(genre)["rating_count_tot"].sum()/apple_group.get_group("Book")["rating_count_tot"].count()
#                  for genre in apple_group.groups.keys()}

# %%
apple_popular = {}
for genre in apple_group.groups.keys():
    total_user_rating = apple_group.get_group(genre)["rating_count_tot"].sum()
    num_user_rating = apple_group.get_group(genre)["rating_count_tot"].count()
    apple_popular[genre] = round(total_user_rating/num_user_rating, 2)

# %%
apple_popular.items()
# Out:
# dict_items([('Book', 46384.92), ('Business', 7491.12), ('Catalogs', 4004.0), ('Education', 7003.98), ('Entertainment', 14195.36), ('Finance', 32367.03), ('Food & Drink', 33333.92), ('Games', 22910.83), ('Health & Fitness', 23298.02), ('Lifestyle', 16815.48), ('Medical', 612.0), ('Music', 57326.53), ('Navigation', 86090.33), ('News', 21248.02), ('Photo & Video', 28441.54), ('Productivity', 21028.41), ('Reference', 79350.47), ('Shopping', 27230.73), ('Social Networking', 71548.35), ('Sports', 23008.9), ('Travel', 28243.8), ('Utilities', 19156.49), ('Weather', 52279.89)])

# %%
apple_popular = dict(sorted(apple_popular.items(), key=lambda x: x[1], reverse=True))
apple_popular
# Out:
# {'Navigation': 86090.33,
#  'Reference': 79350.47,
#  'Social Networking': 71548.35,
#  'Music': 57326.53,
#  'Weather': 52279.89,
#  'Book': 46384.92,
#  'Food & Drink': 33333.92,
#  'Finance': 32367.03,
#  'Photo & Video': 28441.54,
#  'Travel': 28243.8,
#  'Shopping': 27230.73,
#  'Health & Fitness': 23298.02,
#  'Sports': 23008.9,
#  'Games': 22910.83,
#  'News': 21248.02,
#  'Productivity': 21028.41,
#  'Utilities': 19156.49,
#  'Lifestyle': 16815.48,
#  'Entertainment': 14195.36,
#  'Business': 7491.12,
#  'Education': 7003.98,
#  'Catalogs': 4004.0,
#  'Medical': 612.0}

# %% [markdown]
# Navigation, Reference, Social Networking, Music and Weather apps have user rating  above 50,000, with Navigation apps being the highest. These are the most popular apps on apple store
#
# Let's further investigate these 5 genre of apps

# %%
# In percentage
apple_popular = {item[0]: round(item[1]/sum(apple_popular.values())*100, 4) for item in apple_popular.items()}
apple_popular
# Out:
# {'Navigation': 11.9013,
#  'Reference': 10.9696,
#  'Social Networking': 9.891,
#  'Music': 7.9249,
#  'Weather': 7.2273,
#  'Book': 6.4123,
#  'Food & Drink': 4.6081,
#  'Finance': 4.4745,
#  'Photo & Video': 3.9318,
#  'Travel': 3.9045,
#  'Shopping': 3.7644,
#  'Health & Fitness': 3.2208,
#  'Sports': 3.1808,
#  'Games': 3.1672,
#  'News': 2.9374,
#  'Productivity': 2.907,
#  'Utilities': 2.6482,
#  'Lifestyle': 2.3246,
#  'Entertainment': 1.9624,
#  'Business': 1.0356,
#  'Education': 0.9682,
#  'Catalogs': 0.5535,
#  'Medical': 0.0846}

# %% [markdown]
# We can see that the about 48% of the market is dominated by the top five app genre (Navigation, Reference, Social Networking, Music and Weather). Thus we can carve a niche for our new app in either Book, Food & Drink, Fiance, Photo & Video categories, and so on.
#
# Below are the apps that dominated the top genres in apple store

# %%
navigation = apple_group.get_group("Navigation")

# %%
navigation
# Out:
#              id                                        track_name  size_bytes  \
# 3987  344176018  ImmobilienScout24: Real Estate Search in Germany   126867456
# 881   329541503                                       Geocaching®   108166144
# 130   585027354                Google Maps - Navigation & Transit   120232960
# 49    323229106   Waze - GPS Navigation, Maps & Real-time Traffic    94139392
# 6033  463431091                              Railway Route Search    46950400
# 1633  504677517       CoPilot GPS – Car Navigation & Offline Maps    82534400
#
#      currency  price  rating_count_tot  rating_count_ver  user_rating  \
# 3987      USD    0.0               187                 0          3.5
# 881       USD    0.0             12811               134          3.5
# 130       USD    0.0            154911              1253          4.5
# 49        USD    0.0            345046              3040          4.5
# 6033      USD    0.0                 5                 0          3.0
# 1633      USD    0.0              3582                70          4.0
#
#       user_rating_ver         ver cont_rating prime_genre  sup_devices.num  \
# 3987              0.0         9.5          4+  Navigation               37
# 881               1.5         5.3          4+  Navigation               37
# 130               4.0      4.31.1         12+  Navigation               37
# 49                4.5        4.24          4+  Navigation               37
# 6033              0.0      3.17.1          4+  Navigation               37
# 1633              3.5  10.0.0.984          4+  Navigation               38
#
#       ipadSc_urls.num  lang.num  vpp_lic app_language
# 3987                5         3        1      english
# 881                 0        22        1      english
# 130                 5        34        1      english
# 49                  5        36        1      english
# 6033                0         1        1      english
# 1633                5        25        1      english

# %% [markdown]
# The navigation apps are already taken over by the big tech companies like Google maps and Waze.

# %%
apple_group.get_group("Navigation").plot.bar(x = "track_name", y = "rating_count_tot", figsize=(10, 8))
plt.show()

# %%
apple_group.get_group("Navigation").sort_values(by="rating_count_tot", ascending=False).head()
# Out:
#              id                                        track_name  size_bytes  \
# 49    323229106   Waze - GPS Navigation, Maps & Real-time Traffic    94139392
# 130   585027354                Google Maps - Navigation & Transit   120232960
# 881   329541503                                       Geocaching®   108166144
# 1633  504677517       CoPilot GPS – Car Navigation & Offline Maps    82534400
# 3987  344176018  ImmobilienScout24: Real Estate Search in Germany   126867456
#
#      currency  price  rating_count_tot  rating_count_ver  user_rating  \
# 49        USD    0.0            345046              3040          4.5
# 130       USD    0.0            154911              1253          4.5
# 881       USD    0.0             12811               134          3.5
# 1633      USD    0.0              3582                70          4.0
# 3987      USD    0.0               187                 0          3.5
#
#       user_rating_ver         ver cont_rating prime_genre  sup_devices.num  \
# 49                4.5        4.24          4+  Navigation               37
# 130               4.0      4.31.1         12+  Navigation               37
# 881               1.5         5.3          4+  Navigation               37
# 1633              3.5  10.0.0.984          4+  Navigation               38
# 3987              0.0         9.5          4+  Navigation               37
#
#       ipadSc_urls.num  lang.num  vpp_lic app_language
# 49                  5        36        1      english
# 130                 5        34        1      english
# 881                 0        22        1      english
# 1633                5        25        1      english
# 3987                5         3        1      english

# %%
# apple_group.get_group("Reference").plot.bar(x = "track_name", y = "rating_count_tot", figsize=(10, 8))
# plt.show()
apple_group.get_group("Reference").sort_values(by="rating_count_tot", ascending=False).head()
# Out:
#             id                                         track_name  size_bytes  \
# 6    282935706                                              Bible    92774400
# 90   308750436              Dictionary.com Dictionary & Thesaurus   111275008
# 335  364740856     Dictionary.com Dictionary & Thesaurus for iPad   165748736
# 551  414706506                                   Google Translate    65281024
# 715  388389451  Muslim Pro: Ramadan 2017 Prayer Times, Azan, Q...   100551680
#
#     currency  price  rating_count_tot  rating_count_ver  user_rating  \
# 6        USD    0.0            985920              5320          4.5
# 90       USD    0.0            200047               177          4.0
# 335      USD    0.0             54175             10176          4.5
# 551      USD    0.0             26786                27          3.5
# 715      USD    0.0             18418               706          4.5
#
#      user_rating_ver     ver cont_rating prime_genre  sup_devices.num  \
# 6                5.0   7.5.1          4+   Reference               37
# 90               4.0   7.1.3          4+   Reference               37
# 335              4.5     4.0          4+   Reference               24
# 551              4.5  5.10.0          4+   Reference               37
# 715              5.0   9.2.1          4+   Reference               37
#
#      ipadSc_urls.num  lang.num  vpp_lic app_language
# 6                  5        45        1      english
# 90                 0         1        1      english
# 335                5         9        1      english
# 551                5        59        1      english
# 715                5        16        1      english

# %%
# apple_group.get_group("Social Networking").plot.bar(x = "track_name", y = "rating_count_tot", figsize=(10, 8))
apple_group.get_group("Social Networking").sort_values(by="rating_count_tot", ascending=False).head()
# Out:
#            id        track_name  size_bytes currency  price  rating_count_tot  \
# 0   284882215          Facebook   389879808      USD    0.0           2974676
# 5   429047995         Pinterest    74778624      USD    0.0           1061624
# 43  304878510  Skype for iPhone   133238784      USD    0.0            373519
# 48  454638411         Messenger   275729408      USD    0.0            351466
# 51  305343404            Tumblr   151573504      USD    0.0            334293
#
#     rating_count_ver  user_rating  user_rating_ver     ver cont_rating  \
# 0                212          3.5              3.5    95.0          4+
# 5               1814          4.5              4.0    6.26         12+
# 43               127          3.5              4.0  6.35.1          4+
# 48               892          3.0              3.0   119.0          4+
# 51               919          4.0              4.0     8.6         17+
#
#           prime_genre  sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic  \
# 0   Social Networking               37                1        29        1
# 5   Social Networking               37                5        27        1
# 43  Social Networking               37                0        32        1
# 48  Social Networking               37                1        33        1
# 51  Social Networking               37                5        16        1
#
#    app_language
# 0       english
# 5       english
# 43      english
# 48      english
# 51      english

# %%
# apple_group.get_group("Weather").plot.bar(x = "track_name", y = "rating_count_tot", figsize=(10, 8))
# plt.show()
apple_group.get_group("Weather").sort_values(by="rating_count_tot", ascending=False).head()
# Out:
#             id                                         track_name  size_bytes  \
# 22   295646461      The Weather Channel: Forecast, Radar & Alerts   199734272
# 89   364252504  The Weather Channel App for iPad – best local ...    59101184
# 95   281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 133  322439990                MyRadar NOAA Weather Radar Forecast   127284224
# 138  300048137                     AccuWeather - Weather for Life   181941248
#
#     currency  price  rating_count_tot  rating_count_ver  user_rating  \
# 22       USD    0.0            495626              5893          3.5
# 89       USD    0.0            208648             25664          4.0
# 95       USD    0.0            188583              2822          3.5
# 133      USD    0.0            150158              3392          4.5
# 138      USD    0.0            144214              2162          3.5
#
#      user_rating_ver     ver cont_rating prime_genre  sup_devices.num  \
# 22               4.5    8.11          4+     Weather               37
# 89               4.5   4.5.1          4+     Weather               24
# 95               4.5   5.0.0          4+     Weather               37
# 133              5.0   5.1.4          4+     Weather               37
# 138              4.0  10.4.1          4+     Weather               37
#
#      ipadSc_urls.num  lang.num  vpp_lic app_language
# 22                 0        33        1      english
# 89                 4         1        1      english
# 95                 5         3        1      english
# 133                2         8        1      english
# 138                1        43        1      english

# %%
# apple_group.get_group("Music").plot.bar(x = "track_name", y = "rating_count_tot", figsize=(10, 8))
# plt.show()
apple_group.get_group("Music").sort_values(by="rating_count_tot", ascending=False).head()
# Out:
#             id                                         track_name  size_bytes  \
# 4    284035177                            Pandora - Music & Radio   130242560
# 8    324684580                                      Spotify Music   132510720
# 35   284993459  Shazam - Discover music, artists, videos & lyrics   147093504
# 60   290638154          iHeartRadio – Free Music & Radio Stations   116443136
# 151  336353151                         SoundCloud - Music & Audio   105009152
#
#     currency  price  rating_count_tot  rating_count_ver  user_rating  \
# 4        USD    0.0           1126879              3594          4.0
# 8        USD    0.0            878563              8253          4.5
# 35       USD    0.0            402925               136          4.0
# 60       USD    0.0            293228               110          4.0
# 151      USD    0.0            135744               594          4.0
#
#      user_rating_ver     ver cont_rating prime_genre  sup_devices.num  \
# 4                4.5   8.4.1         12+       Music               37
# 8                4.5   8.4.3         12+       Music               37
# 35               4.5  11.0.3         12+       Music               37
# 60               3.0   8.0.0         12+       Music               37
# 151              4.5   5.6.0          4+       Music               37
#
#      ipadSc_urls.num  lang.num  vpp_lic app_language
# 4                  4         1        1      english
# 8                  5        18        1      english
# 35                 3        16        1      english
# 60                 5         2        1      english
# 151                4         7        1      english

# %%
apple_group.get_group("Book").sort_values(by="rating_count_tot", ascending=False).head()
# Out:
#              id                                         track_name  \
# 77    302584613        Kindle – Read eBooks, Magazines & Textbooks
# 208   379693831  Audible – audio books, original series & podcasts
# 244  1031002863       Color Therapy Adult Coloring Book for Adults
# 285   366869252          OverDrive – Library eBooks and Audiobooks
# 364  1024818709                              HOOKED - Chat Stories
#
#      size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 77    169747456      USD    0.0            252076                80
# 208    81558528      USD    0.0            105274              1774
# 244   135236608      USD    0.0             84062              1450
# 285    39844864      USD    0.0             65450              2721
# 364    94545920      USD    0.0             47829               708
#
#      user_rating  user_rating_ver     ver cont_rating prime_genre  \
# 77           3.5              4.5    5.11          4+        Book
# 208          4.5              4.5    2.23          4+        Book
# 244          5.0              4.5     2.0          4+        Book
# 285          4.0              4.5   3.6.4          4+        Book
# 364          4.5              4.5  2.28.0          9+        Book
#
#      sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic app_language
# 77                37                5         9        1      english
# 208               37                5         5        1      english
# 244               37                4         2        1      english
# 285               37                5        18        1      english
# 364               37                0         8        1      english

# %% [markdown]
# ## Most Popular Apps by Genre on Google Play

# %%
google_clean_2.sort_values(by="Installs", ascending=False).head()
# Out:
#                                 App       Category  Rating   Reviews  \
# 465   imo free video calls and chat  COMMUNICATION     4.3   4785988
# 3574                    Cloud Print   PRODUCTIVITY     4.1    282460
# 3235               Google Translate          TOOLS     4.4   5745093
# 3450                 Microsoft Word   PRODUCTIVITY     4.5   2084126
# 1908                 My Talking Tom           GAME     4.5  14892469
#
#                     Size      Installs  Type Price Content Rating  \
# 465                  11M  500,000,000+  Free     0       Everyone
# 3574  Varies with device  500,000,000+  Free     0       Everyone
# 3235  Varies with device  500,000,000+  Free     0       Everyone
# 3450  Varies with device  500,000,000+  Free     0       Everyone
# 1908  Varies with device  500,000,000+  Free     0       Everyone
#
#              Genres    Last Updated         Current Ver         Android Ver  \
# 465   Communication    June 8, 2018    9.8.000000010501          4.0 and up
# 3574   Productivity    May 23, 2018  Varies with device  Varies with device
# 3235          Tools  August 4, 2018  Varies with device  Varies with device
# 3450   Productivity   July 11, 2018    16.0.10325.20043          4.4 and up
# 1908         Casual   July 19, 2018           4.8.0.132          4.1 and up
#
#      app_language
# 465       english
# 3574      english
# 3235      english
# 3450      english
# 1908      english

# %%
# Firstly, converting the "Installs" column to a float
google_clean_2["Installs"] = google_clean_2["Installs"].str.replace("+", "")
google_clean_2["Installs"] = google_clean_2["Installs"].str.replace(",", "")
google_clean_2["Installs"] = google_clean_2["Installs"].astype(float)
google_clean_2["Category"] = google_clean_2["Category"].str.lower()
google_clean_2["Genres"] = google_clean_2["Genres"].str.lower()

# %%
google_clean_2.head()
# Out:
#                                     App          Category  Rating Reviews  \
# 2989             GollerCepte Live Score            sports     4.2    9992
# 4970       Ad Block REMOVER - NEED ROOT             tools     3.3     999
# 2723                SnipSnap Coupon App          shopping     4.2    9975
# 3079  US Open Tennis Championships 2018            sports     4.0    9971
# 3229                         DreamTrips  travel_and_local     4.7    9971
#
#      Size   Installs  Type Price Content Rating          Genres  \
# 2989  31M  1000000.0  Free     0       Everyone          sports
# 4970  91k   100000.0  Free     0       Everyone           tools
# 2723  18M  1000000.0  Free     0       Everyone        shopping
# 3079  33M  1000000.0  Free     0       Everyone          sports
# 3229  22M   500000.0  Free     0           Teen  travel & local
#
#            Last Updated Current Ver Android Ver app_language
# 2989       May 23, 2018         6.5  4.1 and up      english
# 4970  December 17, 2013         3.2  2.2 and up      english
# 2723   January 22, 2018         1.4  4.3 and up      english
# 3079       June 5, 2018         7.1  5.0 and up      english
# 3229     August 6, 2018      1.28.1  5.0 and up      english

# %%
google_group = google_clean_2[google_clean_2["Category"] == google_clean_2["Genres"]]

# %%
google_clean_2.shape
# Out:
# (8846, 14)

# %%
google_group.shape
# Out:
# (4677, 14)

# %%
google_group.head()
# Out:
#                                                     App  Category  Rating  \
# 2989                             GollerCepte Live Score    sports     4.2
# 4970                       Ad Block REMOVER - NEED ROOT     tools     3.3
# 2723                                SnipSnap Coupon App  shopping     4.2
# 3079                  US Open Tennis Championships 2018    sports     4.0
# 7982  Easy Resume Builder, Resume help, Curriculum v...     tools     4.3
#
#      Reviews Size   Installs  Type Price Content Rating    Genres  \
# 2989    9992  31M  1000000.0  Free     0       Everyone    sports
# 4970     999  91k   100000.0  Free     0       Everyone     tools
# 2723    9975  18M  1000000.0  Free     0       Everyone  shopping
# 3079    9971  33M  1000000.0  Free     0       Everyone    sports
# 7982     996  10M    50000.0  Free     0       Everyone     tools
#
#             Last Updated Current Ver   Android Ver app_language
# 2989        May 23, 2018         6.5    4.1 and up      english
# 4970   December 17, 2013         3.2    2.2 and up      english
# 2723    January 22, 2018         1.4    4.3 and up      english
# 3079        June 5, 2018         7.1    5.0 and up      english
# 7982  September 28, 2017         2.3  4.0.3 and up      english

# %%
google_category = google_group.groupby("Category")

# %%
google_category.groups.keys()
# Out:
# dict_keys(['beauty', 'business', 'comics', 'communication', 'dating', 'education', 'entertainment', 'events', 'finance', 'lifestyle', 'medical', 'parenting', 'personalization', 'photography', 'productivity', 'shopping', 'social', 'sports', 'tools', 'weather'])

# %%
category_app = {}

for category in google_category.groups.keys():
    total = google_category.get_group(category)["Installs"].sum()
    len_category = google_category.get_group(category)["Installs"].count()
    category_app[category] = round(total/len_category, 2)
category_app
# Out:
# {'beauty': 513151.89,
#  'business': 1712290.15,
#  'comics': 847380.19,
#  'communication': 38590581.09,
#  'dating': 854028.83,
#  'education': 1671195.65,
#  'entertainment': 12323250.0,
#  'events': 253542.22,
#  'finance': 1387692.48,
#  'lifestyle': 1421219.91,
#  'medical': 120616.49,
#  'parenting': 467977.5,
#  'personalization': 5201482.61,
#  'photography': 17805627.64,
#  'productivity': 16787331.34,
#  'shopping': 7036877.31,
#  'social': 23253652.13,
#  'sports': 3650602.28,
#  'tools': 10711834.42,
#  'weather': 5145550.29}

# %%
category_app = dict(sorted(category_app.items(), key=lambda x: x[1], reverse=True))

# %%
category_app
# Out:
# {'communication': 38590581.09,
#  'social': 23253652.13,
#  'photography': 17805627.64,
#  'productivity': 16787331.34,
#  'entertainment': 12323250.0,
#  'tools': 10711834.42,
#  'shopping': 7036877.31,
#  'personalization': 5201482.61,
#  'weather': 5145550.29,
#  'sports': 3650602.28,
#  'business': 1712290.15,
#  'education': 1671195.65,
#  'lifestyle': 1421219.91,
#  'finance': 1387692.48,
#  'dating': 854028.83,
#  'comics': 847380.19,
#  'beauty': 513151.89,
#  'parenting': 467977.5,
#  'events': 253542.22,
#  'medical': 120616.49}

# %%
category_app = {item[0]: round(item[1]/sum(category_app.values())*100, 4)for item in category_app.items()}
category_app
# Out:
# {'communication': 25.769,
#  'social': 15.5277,
#  'photography': 11.8898,
#  'productivity': 11.2098,
#  'entertainment': 8.2289,
#  'tools': 7.1529,
#  'shopping': 4.6989,
#  'personalization': 3.4733,
#  'weather': 3.436,
#  'sports': 2.4377,
#  'business': 1.1434,
#  'education': 1.1159,
#  'lifestyle': 0.949,
#  'finance': 0.9266,
#  'dating': 0.5703,
#  'comics': 0.5658,
#  'beauty': 0.3427,
#  'parenting': 0.3125,
#  'events': 0.1693,
#  'medical': 0.0805}

# %% [markdown]
# For google app store, about 41% of the app category is dominated by communication and social categories, while the remaining 59% is lead by photography, productivity and entertainment categories
#
# Let's closely examine the top 5 genres of google app store

# %%
# apple_group.get_group("Music").plot.bar(x = "track_name", y = "rating_count_tot", figsize=(10, 8))
# plt.show()
google_category.get_group("communication").sort_values(by="Installs", ascending=False).head()
# Out:
#                                           App       Category  Rating  \
# 382  Messenger – Text and Video Chat for Free  communication     4.0
# 391             Skype - free IM & video calls  communication     4.1
# 464                                  Hangouts  communication     4.0
# 411              Google Chrome: Fast & Secure  communication     4.3
# 451                                     Gmail  communication     4.3
#
#       Reviews                Size      Installs  Type Price Content Rating  \
# 382  56646578  Varies with device  1.000000e+09  Free     0       Everyone
# 391  10484169  Varies with device  1.000000e+09  Free     0       Everyone
# 464   3419513  Varies with device  1.000000e+09  Free     0       Everyone
# 411   9643041  Varies with device  1.000000e+09  Free     0       Everyone
# 451   4604483  Varies with device  1.000000e+09  Free     0       Everyone
#
#             Genres    Last Updated         Current Ver         Android Ver  \
# 382  communication  August 1, 2018  Varies with device  Varies with device
# 391  communication  August 3, 2018  Varies with device  Varies with device
# 464  communication   July 21, 2018  Varies with device  Varies with device
# 411  communication  August 1, 2018  Varies with device  Varies with device
# 451  communication  August 2, 2018  Varies with device  Varies with device
#
#     app_language
# 382      english
# 391      english
# 464      english
# 411      english
# 451      english

# %%
google_category.get_group("social").sort_values(by="Installs", ascending=False).head()
# Out:
#                 App Category  Rating   Reviews                Size  \
# 2554        Google+   social     4.2   4831125  Varies with device
# 2544       Facebook   social     4.1  78158306  Varies with device
# 2604      Instagram   social     4.5  66577446  Varies with device
# 2610       Snapchat   social     4.0  17015352  Varies with device
# 2546  Facebook Lite   social     4.3   8606259  Varies with device
#
#           Installs  Type Price Content Rating  Genres    Last Updated  \
# 2554  1.000000e+09  Free     0           Teen  social   July 26, 2018
# 2544  1.000000e+09  Free     0           Teen  social  August 3, 2018
# 2604  1.000000e+09  Free     0           Teen  social   July 31, 2018
# 2610  5.000000e+08  Free     0           Teen  social   July 30, 2018
# 2546  5.000000e+08  Free     0           Teen  social  August 1, 2018
#
#              Current Ver         Android Ver app_language
# 2554  Varies with device  Varies with device      english
# 2544  Varies with device  Varies with device      english
# 2604  Varies with device  Varies with device      english
# 2610  Varies with device  Varies with device      english
# 2546  Varies with device  Varies with device      english

# %%
google_category.get_group("photography").sort_values(by="Installs", ascending=False).head()
# Out:
#                                                     App     Category  Rating  \
# 2884                                      Google Photos  photography     4.5
# 2945               YouCam Perfect - Selfie Photo Editor  photography     4.5
# 2944  Candy Camera - selfie, beauty camera, photo ed...  photography     4.4
# 5057                                          AR effect  photography     4.2
# 2847  Sweet Selfie - selfie camera, beauty cam, phot...  photography     4.6
#
#        Reviews                Size      Installs  Type Price Content Rating  \
# 2884  10859051  Varies with device  1.000000e+09  Free     0       Everyone
# 2945   1579343  Varies with device  1.000000e+08  Free     0       Everyone
# 2944   3368705  Varies with device  1.000000e+08  Free     0       Everyone
# 5057     79792  Varies with device  1.000000e+08  Free     0       Everyone
# 2847   1159058                 25M  1.000000e+08  Free     0       Everyone
#
#            Genres    Last Updated         Current Ver         Android Ver  \
# 2884  photography  August 6, 2018  Varies with device  Varies with device
# 2945  photography   July 25, 2018  Varies with device  Varies with device
# 2944  photography   July 16, 2018                4.47        4.0.3 and up
# 5057  photography  August 3, 2018  Varies with device  Varies with device
# 2847  photography  August 3, 2018            2.73.672        4.0.3 and up
#
#      app_language
# 2884      english
# 2945      english
# 2944      english
# 5057      english
# 2847      english

# %%
google_category.get_group("productivity").sort_values(by="Installs", ascending=False).head()
# Out:
#                   App      Category  Rating  Reviews                Size  \
# 3565     Google Drive  productivity     4.4  2731211  Varies with device
# 3473          Dropbox  productivity     4.4  1861310                 61M
# 3562  Google Calendar  productivity     4.2   858230  Varies with device
# 3450   Microsoft Word  productivity     4.5  2084126  Varies with device
# 3574      Cloud Print  productivity     4.1   282460  Varies with device
#
#           Installs  Type Price Content Rating        Genres    Last Updated  \
# 3565  1.000000e+09  Free     0       Everyone  productivity  August 6, 2018
# 3473  5.000000e+08  Free     0       Everyone  productivity  August 1, 2018
# 3562  5.000000e+08  Free     0       Everyone  productivity  August 6, 2018
# 3450  5.000000e+08  Free     0       Everyone  productivity   July 11, 2018
# 3574  5.000000e+08  Free     0       Everyone  productivity    May 23, 2018
#
#              Current Ver         Android Ver app_language
# 3565  Varies with device  Varies with device      english
# 3473  Varies with device  Varies with device      english
# 3562  Varies with device  Varies with device      english
# 3450    16.0.10325.20043          4.4 and up      english
# 3574  Varies with device  Varies with device      english

# %%
google_category.get_group("entertainment").sort_values(by="Installs", ascending=False).head()
# Out:
#                      App       Category  Rating  Reviews                Size  \
# 958              Netflix  entertainment     4.4  5456708  Varies with device
# 866              Hotstar  entertainment     4.3  4885646  Varies with device
# 893  Talking Ben the Dog  entertainment     4.3  1633682                 57M
# 874       Talking Angela  entertainment     3.7  1828284                 52M
# 930     IMDb Movies & TV  entertainment     4.2   501498                 12M
#
#         Installs  Type Price Content Rating         Genres    Last Updated  \
# 958  100000000.0  Free     0           Teen  entertainment   July 31, 2018
# 866  100000000.0  Free     0           Teen  entertainment  August 3, 2018
# 893  100000000.0  Free     0       Everyone  entertainment    July 3, 2018
# 874  100000000.0  Free     0       Everyone  entertainment   July 12, 2018
# 930  100000000.0  Free     0           Teen  entertainment   July 26, 2018
#
#             Current Ver         Android Ver app_language
# 958  Varies with device  Varies with device      english
# 866  Varies with device  Varies with device      english
# 893             3.5.2.2          4.1 and up      english
# 874               2.8.2          4.1 and up      english
# 930  Varies with device  Varies with device      english

# %%
google_category.get_group("tools").sort_values(by="Installs", ascending=False).head()
# Out:
#                                                     App Category  Rating  \
# 3234                                             Google    tools     4.4
# 4005            Clean Master- Space Cleaner & Antivirus    tools     4.7
# 3235                                   Google Translate    tools     4.4
# 7536  Security Master - Antivirus, VPN, AppLock, Boo...    tools     4.7
# 3265                       Gboard - the Google Keyboard    tools     4.2
#
#        Reviews                Size      Installs  Type Price Content Rating  \
# 3234   8033493  Varies with device  1.000000e+09  Free     0       Everyone
# 4005  42916526  Varies with device  5.000000e+08  Free     0       Everyone
# 3235   5745093  Varies with device  5.000000e+08  Free     0       Everyone
# 7536  24900999  Varies with device  5.000000e+08  Free     0       Everyone
# 3265   1859115  Varies with device  5.000000e+08  Free     0       Everyone
#
#      Genres    Last Updated         Current Ver         Android Ver  \
# 3234  tools  August 3, 2018  Varies with device  Varies with device
# 4005  tools  August 3, 2018  Varies with device  Varies with device
# 3235  tools  August 4, 2018  Varies with device  Varies with device
# 7536  tools  August 4, 2018               4.6.6  Varies with device
# 3265  tools   July 31, 2018  Varies with device  Varies with device
#
#      app_language
# 3234      english
# 4005      english
# 3235      english
# 7536      english
# 3265      english

# %% [markdown]
# ### Conclusion
#
# Presently, the market is dominated by apps from big tech companies, it might be easier for us to launch our entry into the market by launching  a free app by looking at categories like Photography, Music and Entertainment
